# %%
fab <- c(4,2,1,2,2,3,3,2,1,1)

# %%
table(fab)
# Out:
# fab
# 1 2 3 4
# 3 4 2 1

# %%
pie(table(fab))
# Out:
# plot without title

# %%
barplot(table(fab), names=c('봄','여름','가을','겨울'), col=c('pink','skyblue',''),main='계절 선호도 조사', xlab='계절',ylab='응답수')
# Out:
# Plot with title "계절 선호도 조사"
