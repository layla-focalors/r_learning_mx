# %%
survey = c(T, F, T, T, F, T, F, F, T, T)
survey
# Out:
#  [1]  TRUE FALSE  TRUE  TRUE FALSE  TRUE FALSE FALSE  TRUE  TRUE

# %%
barplot(table(survey),names = c('No', 'Yes'),
       col = c('#a8dadc', '#1d3557'))
# Out:
# plot without title

# %%
barplot(table(mtcars$cyl), horiz = T,
       main = "실린더 종류별 분포",
       ylab = '실린더의 수',
       las = 2, 
       col = c('salmon','snow','pink'))
# Out:
# Plot with title "실린더 종류별 분포"

# %%
ds = sleep$extra

# %%
ds
# Out:
#  [1]  0.7 -1.6 -0.2 -1.2 -0.1  3.4  3.7  0.8  0.0  2.0  1.9  0.8  1.1  0.1 -0.1
# [16]  4.4  5.5  1.6  4.6  3.4

# %%
hist(ds, 
    main = 'Histogram of Sleep',
    xlab = 'increase in hours of sleep',
    breaks = 4, 
    col = 'pink')
# Out:
# Plot with title "Histogram of Sleep"

# %%
barplot(table(mtcars$cyl, mtcars$gear),
       beside = T,
       main = 'Distibution of Carburetors',
       xlab = 'Number of Gear',
       ylab = 'Frequency',
       legend.text = c('cyl 4','cyl 6', 'cyl 8'),
       args.legend = list(bty = 'n'))
# Out:
# Plot with title "Distibution of Carburetors"

# %%
ds = trees$Height

# %%
ds
# Out:
#  [1] 70 65 63 72 81 83 66 75 80 75 79 76 76 69 75 74 85 86 71 64 78 80 74 72 77
# [26] 81 82 80 80 80 87

# %%
color.6 = rep('#f1faee', 6)

# %%
color.6
# Out:
# [1] "#f1faee" "#f1faee" "#f1faee" "#f1faee" "#f1faee" "#f1faee"

# %%
color.6[3:5] = '#e63946'

# %%
color.6
# Out:
# [1] "#f1faee" "#f1faee" "#e63946" "#e63946" "#e63946" "#f1faee"

# %%
hist(ds, main = 'Histogram of Black Cherry Trees',
    xlab = 'Height(ft)',
    las = 1,
    breaks = 4,
    col = color.6)
# Out:
# Plot with title "Histogram of Black Cherry Trees"

# %%
male = c(6.9, 30.4, 80.4)
female = c(4.9, 38.2, 82.7)

# %%
ds = rbind(male, female)

# %%
ds
# Out:
#        [,1] [,2] [,3]
# male   6.9  30.4 80.4
# female 4.9  38.2 82.7

# %%
colnames(ds) = c('Samsung', 'apple', 'huawei')

# %%
ds
# Out:
#        Samsung apple huawei
# male   6.9     30.4  80.4
# female 4.9     38.2  82.7

# %%
barplot(ds, horiz = T,
       beside = T,
       main = '성별에 따른 브랜드 선호도',
       las = 1,
       legend.text = c('여자','남자'),
       args.legend = list(x='right',bty = 'n', inset = c(-0.2, 0)))
# Out:
# Plot with title "성별에 따른 브랜드 선호도"

# %%
holiday = c(14, 15, 15, 16, 14, 11, 12)
holiday.actual = c(15, 35, 38, 36, 34, 32, 32)
ds = rbind(holiday, holiday.actual)

# %%
ds
# Out:
#                [,1] [,2] [,3] [,4] [,5] [,6] [,7]
# holiday        14   15   15   16   14   11   12
# holiday.actual 15   35   38   36   34   32   32

# %%
colnames(ds) = c('한국','일본','독일','러시아','미국','프랑스', '호주')

# %%
barplot(ds, beside = T,
       main = '주요 국가별 공휴일 현황',
       xlab = '국가',
       legend.text = c('공휴일 수', '실제 쉬는 날'),
       args.legend = list(x='topleft', bty = 'n', inset = c(-0.1, -0.13)))
# Out:
# Plot with title "주요 국가별 공휴일 현황"

# %%
d2016 = c(104359, 3393, 24527, 7058, 102, 975)
d2017 = c(116215, 3437, 26183, 7522, 147, 1411)

# %%
ds = rbind(d2016, d2017)

# %%
ds
# Out:
#       [,1]   [,2] [,3]  [,4] [,5] [,6]
# d2016 104359 3393 24527 7058 102   975
# d2017 116215 3437 26183 7522 147  1411

# %%
colnames(ds) = c('시','소설','수필','평론','희곡','기타')

# %%
ds
# Out:
#       시     소설 수필  평론 희곡 기타
# d2016 104359 3393 24527 7058 102   975
# d2017 116215 3437 26183 7522 147  1411

# %%
barplot(ds, main = '문인잡지의 발표 현황',
       xlab = '작품 종류',
       ylab = '발표 건수',
       legend.text = c('2016','2017'),
       col = c('maroon','indianred'))
# Out:
# Plot with title "문인잡지의 발표 현황"
